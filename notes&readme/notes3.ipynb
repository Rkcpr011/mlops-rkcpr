# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# objective function pura training prediction ko define krta hai.
# max_evals ye btata hai ki objective function kitni bar chalega.
# trials sare runs ke pearameters ko store krta hai like a memory.
# algo help krta hai which set of parameter to choose next to minimize the loss.
# space  deta hai parameters  ki all possible values.
