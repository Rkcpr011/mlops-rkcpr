# %% [markdown]
# step1: run mlflow server

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# step2 run traning pipeline:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# step 3 run fast api

# %% [markdown]
# ![image.png](attachment:image.png)
